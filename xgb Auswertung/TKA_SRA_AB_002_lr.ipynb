# %% [markdown]
# # Auswirkung der learning rate auf XGB-Modell

# %% [markdown]
# #### Importe

# %%
import torch
from torch import nn
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.metrics import r2_score as r2
from sklearn.metrics import max_error
import seaborn as sns

# %% [markdown]
# #### Laden des Train und Testloss über den Trainingsverlauf

# %%
# Standardisierungsdaten
loss_data_file_1 = Path.cwd().parent / 'data' / 'models' / 'hyperparams' / 'loss_011_003.npz'
loss_data_1 = np.load(loss_data_file_1)
loss_data_file_2 = Path.cwd().parent / 'data' / 'models' / 'hyperparams' / 'loss_011_005.npz'
loss_data_2 = np.load(loss_data_file_2)
loss_data_file_3 = Path.cwd().parent / 'data' / 'models' / 'hyperparams' / 'loss_011_006.npz'
loss_data_3 = np.load(loss_data_file_3)
loss_data_file_4 = Path.cwd().parent / 'data' / 'models' / 'hyperparams' / 'loss_011_007.npz'
loss_data_4 = np.load(loss_data_file_4)

train_loss_1 = np.array(loss_data_1['train_loss'])
test_loss_1 = np.array(loss_data_1['test_loss'])
train_loss_2 = np.array(loss_data_2['train_loss'])
test_loss_2 = np.array(loss_data_2['test_loss'])
train_loss_3 = np.array(loss_data_3['train_loss'])
test_loss_3 = np.array(loss_data_3['test_loss'])
train_loss_4 = np.array(loss_data_4['train_loss'])
test_loss_4 = np.array(loss_data_4['test_loss'])

# %% [markdown]
# #### Importing Plot Stylesheet

# %%
plt.style.use(['seaborn-v0_8-paper',Path.cwd().parent / 'plotstyle' / 'paper.mplstyle'])
cm = cm = 1/2.54

# %% [markdown]
# #### Plot loss vs epoch

# %%
fig,ax = plt.subplots(figsize=(9.75*cm, 6.5*cm))

ax.semilogy(train_loss_1, '-', color = 'darkmagenta', label='lr = 0,3, train')
ax.semilogy(test_loss_1, '--', color = 'darkmagenta', label='lr = 0,3, test')
ax.semilogy(train_loss_2, '-', color = 'cadetblue', label='lr = 0,2, train')
ax.semilogy(test_loss_2, '--', color = 'cadetblue', label='lr = 0,2, test')
ax.semilogy(train_loss_3, '-', color = 'darkorange', label='lr = 0,1, train')
ax.semilogy(test_loss_3, '--', color = 'darkorange', label='lr = 0,1, test')
ax.semilogy(train_loss_4, '-', color = 'crimson', label='lr = 0,05, train')
ax.semilogy(test_loss_4, '--', color = 'crimson', label='lr = 0,05, test')
#plt.title("Train and Test Loss")
ax.set(xlabel = 'Rounds / 1', ylabel = 'L1 Loss / 1') #Beschriftung Achsen; Kursiv durch $$; Index durch _{}
ax.set(xlim=(0,480))
ax.tick_params(direction = 'in') #, length = 20, width = 3)

plt.legend(ncol = 2)
plt.tight_layout()
plt.show()

# %%
#fig.savefig(Path.cwd().parent / 'plots/xgb/TKA_SRA_PB_016_lr.png', bbox_inches = 'tight')
