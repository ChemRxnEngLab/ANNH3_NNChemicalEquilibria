# %% [markdown]
# # Auswirkung der Layeranzahl auf neuronales Netz

# %% [markdown]
# #### Importe

# %%
import torch
from torch import nn
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.metrics import r2_score as r2
from sklearn.metrics import max_error
import seaborn as sns

# %% [markdown]
# #### Laden des Train und Testloss über den Trainingsverlauf

# %%
# Standardisierungsdaten
loss_data_file_1 = Path.cwd().parent / 'data' / 'models' / 'hyperparams' / 'loss_011_001.npz'
loss_data_1 = np.load(loss_data_file_1)
loss_data_file_2 = Path.cwd().parent / 'data' / 'models' / 'hyperparams' / 'loss_011_002.npz'
loss_data_2 = np.load(loss_data_file_2)
loss_data_file_3 = Path.cwd().parent / 'data' / 'models' / 'hyperparams' / 'loss_011_003.npz'
loss_data_3 = np.load(loss_data_file_3)
loss_data_file_4 = Path.cwd().parent / 'data' / 'models' / 'hyperparams' / 'loss_011_004.npz'
loss_data_4 = np.load(loss_data_file_4)

train_loss_1 = np.array(loss_data_1['train_loss'])
test_loss_1 = np.array(loss_data_1['test_loss'])
train_loss_2 = np.array(loss_data_2['train_loss'])
test_loss_2 = np.array(loss_data_2['test_loss'])
train_loss_3 = np.array(loss_data_3['train_loss'])
test_loss_3 = np.array(loss_data_3['test_loss'])
train_loss_4 = np.array(loss_data_4['train_loss'])
test_loss_4 = np.array(loss_data_4['test_loss'])

# %% [markdown]
# #### Importing Plot Stylesheet

# %%
plt.style.use(['seaborn-v0_8-paper',Path.cwd().parent / 'plotstyle' / 'paper.mplstyle'])

# %% [markdown]
# #### Plot loss vs epoch

# %%
fig,ax = plt.subplots()

ax.semilogy(train_loss_1, '-', color = 'darkmagenta', label='max depth = 6, train')
ax.semilogy(test_loss_1, '--', color = 'darkmagenta', label='max depth = 6, test')
ax.semilogy(train_loss_2, '-', color = 'cadetblue', label='max depth = 4, train')
ax.semilogy(test_loss_2, '--', color = 'cadetblue', label='max depth = 4, test')
ax.semilogy(train_loss_3, '-', color = 'darkorange', label='max depth = 3, train')
ax.semilogy(test_loss_3, '--', color = 'darkorange', label='max depth = 3, test')
ax.semilogy(train_loss_4, '-', color = 'crimson', label='max depth = 2, train')
ax.semilogy(test_loss_4, '--', color = 'crimson', label='max depth = 2, test')
#plt.title("Train and Test Loss")
ax.set(xlabel = 'Rounds / 1', ylabel = 'L1 Loss / 1') #Beschriftung Achsen; Kursiv durch $$; Index durch _{}
ax.set(xlim=(0,175))
ax.tick_params(direction = 'in') #, length = 20, width = 3)

plt.legend(ncol = 2)
plt.tight_layout()
plt.show()

# %%
#fig.savefig(Path.cwd().parent / 'plots/xgb/TKA_SRA_PB_001_depth.png', bbox_inches = 'tight')
