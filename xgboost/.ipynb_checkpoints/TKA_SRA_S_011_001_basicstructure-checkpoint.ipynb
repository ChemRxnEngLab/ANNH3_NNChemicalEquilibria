# %% [markdown]
# # XGBoost Architektur

# %% [markdown]
# #### Importe

# %%
import matplotlib.pyplot as plt
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score as r2
from sklearn.metrics import max_error
from sklearn.model_selection import RandomizedSearchCV
from pathlib import Path

# %% [markdown]
# #### Gleichgewichtsdaten importieren

# %%
eq_data_file = Path.cwd().parent / 'data' / 'eq_dataset_x.npz' #Import der GGW Daten
res = np.load(eq_data_file)

# Bei Speicherung wurden Daten als T, p, x_0 und x gespeichert
# Inputs T, p, x_0[H2,N2,NH3]
# Output x[H2,N2,NH3]
T = np.array(res['T'])
p = np.array(res['p'])
x_0 = np.array(res['x_0'])
x = np.array(res['x'])

#print(x_0)

X = np.stack((T, p, x_0[:,0], x_0[:,1], x_0[:,2]), axis = 1)
y = np.stack((x[:,0], x[:,2]), axis = 1) # [x_H2, x_NH3]
#print(X[:,0])

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size= 0.8, random_state = 42)

#print(y_train)

# %% [markdown]
# #### Normalisierung

# %%
# Preprocessing Normalisierung der Daten
mean_in = np.mean(X_train, 0) # Mittelwert
std_in = np.std(X_train, 0) # Standardabweichung
mean_out = y_train.mean()
std_out = np.std(y_train, 0)

X_train = (X_train - mean_in) / std_in
y_train = (y_train - mean_out) / std_out

X_test = (X_test -mean_in) / std_in
y_test = (y_test - mean_out) / std_out

# print(mean_in)
# print(std_in)
# print(X_train)
# print(np.mean(X_train[:,0]))

# %% [markdown]
# #### DMatrix

# %%
# Erstellen von Regressionsmatrizen
dtrain = xgb.DMatrix(X_train, y_train)
dtest = xgb.DMatrix(X_test, y_test)

# %% [markdown]
# #### Hyperparameter

# %%
# Definition von Hyperparametern
params = {"objective": "reg:squarederror",
          "max_depth": 6, #default=6
          "learning_rate": 0.3, #default= 0.3
          "colsample_bytree": 1, #default=1 fraction of columns to be randomly sampled for each tree; might improve overfitting
          "subsample": 1, #default=1  fraction of observations to be sampled for each tree
         }
evals = [(dtrain, "train"), (dtest, "validation")]

n = 10000

# %% [markdown]
# #### XGBoost Modell

# %%
xgb_model = xgb.train(params = params, 
                      dtrain = dtrain, 
                      num_boost_round = n, 
                      evals = evals, 
                      verbose_eval = 50, # gibt nur alle x Runden aus
                      early_stopping_rounds = 50 # bricht Training ab, wenn val_loss sich für x Runden nicht verbessert
                     )

#xgb_model.fit(X_train, y_train, eval_set = [(X_test, y_test)])
# score_xgb_train = xgb_model.score(X_train, y_train)
# score_xgb_test = xgb_model.score(X_test, y_test)
# print('R^2 Train:', score_xgb_train)
# print('R^2 Test:', score_xgb_test)
# Out:
# [0]	train-rmse:1.37897	validation-rmse:1.39883
# [50]	train-rmse:0.01455	validation-rmse:0.11427
# [100]	train-rmse:0.00454	validation-rmse:0.11355
# [150]	train-rmse:0.00172	validation-rmse:0.11325
# [200]	train-rmse:0.00156	validation-rmse:0.11324
# [203]	train-rmse:0.00156	validation-rmse:0.11324

# %% [markdown]
# #### Vorhersage Gleichgewichtsdaten

# %%
# Vorhersage der GGW Daten
pred_train_norm = xgb_model.predict(dtrain)
pred_test_norm = xgb_model.predict(dtest)

# Denormalisierung
pred_train = pred_train_norm * std_out + mean_out
real_train = y_train * std_out + mean_out
pred_test = pred_test_norm * std_out + mean_out
real_test = y_test * std_out + mean_out

mae_train = (abs(real_train - pred_train)).mean()
mae_test = (abs(real_test - pred_test)).mean()
mre_train = (abs((real_train - pred_train) / real_train)).mean()
mre_test = (abs((real_test - pred_test) / real_test)).mean()

print('MAE Train:', mae_train, 'MRE Train:', mre_train, 'MAE Test:', mae_test, 'MRE Test:', mre_test)
# Out:
# MAE Train: 0.00014951724986615606 MRE Train: 0.0006581184902556336 MAE Test: 0.010558692555530175 MRE Test: 0.05027175856074777

# %% [markdown]
# #### Parity Plot

# %%
print('Training Dataset: R^2 =', r2(real_train,pred_train))
print('Test Dataset: R^2 =', r2(real_test,pred_test))
print('Max Error Training: |x_H2 - x_H2_pred| =', max_error(real_train[0], pred_train[0]), '|x_NH3 - x_NH3_pred| =', max_error(real_train[1], pred_train[1]))
print('Max Error Test: |x_H2 - x_H2_pred| =', max_error(real_test[0], pred_test[0]), '|x_NH3 - x_NH3_pred| =', max_error(real_test[1], pred_test[1]))

# find the boundaries of X and Y values
bounds = (min(real_train.min(), pred_train.min()) - int(0.1 * pred_train.min()), max(real_train.max(), pred_train.max())+ int(0.1 * pred_train.max()))

fig,ax = plt.subplots(1,2, figsize =(10,10))

# # Reset the limits
# ax[0] = plt.gca()
ax[0].set_xlim(bounds)
ax[0].set_ylim(bounds)
# Ensure the aspect ratio is square
ax[0].set_aspect("equal", adjustable="box")

ax[0].plot(real_train, pred_train, '.', label = (['$x\mathregular{_{H_2}}$', '$x\mathregular{_{NH_3}}$']))
ax[0].plot([0, 1], [0, 1], "r-",lw=2 ,transform=ax[0].transAxes)
ax[0].plot([bounds[0],bounds[1]], [bounds[0] * 1.1, bounds[1]*1.1], "k--", label = ('\xb1' '10%')) # Error line
ax[0].plot([bounds[0],bounds[1]], [bounds[0] * 0.9, bounds[1]*0.9], "k--") # Error line
ax[0].set(xlabel = '$x$ / 1', ylabel = '$x\mathregular{_{pred}}$ / 1')
ax[0].tick_params(direction = 'in') #, length = 20, width = 3)
ax[0].set_title('Train Data')
ax[0].legend()

# Reset the limits
#ax[1] = plt.gca()
ax[1].set_xlim(bounds)
ax[1].set_ylim(bounds)
# Ensure the aspect ratio is square
ax[1].set_aspect("equal", adjustable="box")

ax[1].plot(real_test, pred_test, '.', label = (['$x\mathregular{_{H_2}}$', '$x\mathregular{_{NH_3}}$']))
ax[1].plot([0, 1], [0, 1], "r-",lw=2 ,transform=ax[1].transAxes)
ax[1].plot([bounds[0],bounds[1]], [bounds[0] * 1.1, bounds[1]*1.1], "k--", label = ('\xb1' '10%')) # Error line
ax[1].plot([bounds[0],bounds[1]], [bounds[0] * 0.9, bounds[1]*0.9], "k--") # Error line
ax[1].set(xlabel = '$x$ / 1', ylabel = '$x\mathregular{_{pred}}$ / 1')
ax[1].tick_params(direction = 'in') #, length = 20, width = 3)
ax[1].set_title('Test Data')
ax[1].legend()

#plt.legend()
#fig.suptitle("Parity Plot")
plt.tight_layout()
plt.show()
# Out:
# Training Dataset: R^2 = 0.9999975725841865
# Test Dataset: R^2 = 0.9867322071537873
# Max Error Training: |x_H2 - x_H2_pred| = 0.0005605784064041108 |x_NH3 - x_NH3_pred| = 0.0002726836468506799
# Max Error Test: |x_H2 - x_H2_pred| = 0.0030843750670547787 |x_NH3 - x_NH3_pred| = 0.047138612237012434

# %% [markdown]
# #### Cross-Validation

# %%
params = {"objective": "reg:squarederror", "tree_method": "hist"}
n = 1000

results = xgb.cv(
   params, dtrain,
   num_boost_round = n,
   nfold = 5,
   early_stopping_rounds = 20
)
print(results.head())

best_loss, best_round = results['test-rmse-mean'].min(), results['test-rmse-mean'].idxmin()
print('Best loss:', best_loss, 'Round:', best_round)
# Out:
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         1.380653        0.007482        1.384559       0.035164
# 1         0.987312        0.005327        0.998745       0.027710
# 2         0.709325        0.003942        0.727808       0.022920
# 3         0.513083        0.002584        0.539768       0.019523
# 4         0.373660        0.002223        0.410636       0.017865
# Best loss: 0.13619075966589303 Round: 118

# %% [markdown]
# #### RandomizedSearch CV

# %%
# Liste der zu tunenden Hyperparameter
params = {"objective": ["reg:squarederror", "reg:squaredlogerror", "reg:logistic", "reg:pseudohubererror", "reg:absoluteerror"],
          "max_depth": [3, 5, 6, 8, 10, 15], #default=6
          "learning_rate": [0.01, 0.05, 0.1, 0.2, 0.3, 0.4], #default= 0.3
          "colsample_bytree": np.arange(0.4, 1.0, 0.1), #default=1 fraction of columns to be randomly sampled for each tree; might improve overfitting
          "subsample": np.arange(0.5, 1.0, 0.1), #default=1  fraction of observations to be sampled for each tree
          "colsample_bylevel": np.arange(0.4, 1.0, 0.1),
          "n_estimators": np.arange(50, 1000, 10)
         }

# Neues XGBoost Objekt
knn_model_2 = xgb.XGBRegressor()

model = RandomizedSearchCV(knn_model_2, params, n_iter=25)
best_model = model.fit(X_train, y_train)

print('Best parameters:', best_model.best_params_)
best_objective = best_model.best_estimator_.get_params()['objective']
best_max_depth = best_model.best_estimator_.get_params()['max_depth']
best_learning_rate = best_model.best_estimator_.get_params()['learning_rate']
best_colsample_bytree = best_model.best_estimator_.get_params()['colsample_bytree']
best_subsample = best_model.best_estimator_.get_params()['subsample']
best_colsample_bylevel = best_model.best_estimator_.get_params()['colsample_bylevel']
best_n_estimators = best_model.best_estimator_.get_params()['n_estimators']
# Out:
# C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 75 fits failed out of a total of 125.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [15:16:16] c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:148: label must be greater than -1 for rmsle so that log(label + 1) can be valid.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [15:16:16] c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:148: label must be in [0,1] for logistic regression
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [15:16:16] C:\Users\dev-admin\croot2\xgboost-split_1675461376218\work\include\xgboost/objective.h:98: multioutput is not supported by current objective function
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [15:16:43] c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:148: label must be greater than -1 for rmsle so that log(label + 1) can be valid.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [15:16:43] c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:148: label must be in [0,1] for logistic regression
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [15:17:03] c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:148: label must be greater than -1 for rmsle so that log(label + 1) can be valid.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [15:17:03] c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:148: label must be in [0,1] for logistic regression
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [15:17:21] c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:148: label must be in [0,1] for logistic regression
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [15:17:26] C:\Users\dev-admin\croot2\xgboost-split_1675461376218\work\include\xgboost/objective.h:98: multioutput is not supported by current objective function
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [15:17:49] c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:148: label must be greater than -1 for rmsle so that log(label + 1) can be valid.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [15:17:49] c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:148: label must be in [0,1] for logistic regression
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\sinar\anaconda3\envs\BA\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.98152941        nan        nan        nan 0.95360683 0.98038152
#  0.98386108        nan        nan        nan 0.97749793        nan
#         nan 0.96230166        nan 0.95029104        nan 0.92890071
#  0.97803471        nan        nan        nan        nan        nan
#  0.98520068]
#   warnings.warn(
# Best parameters: {'subsample': 0.7999999999999999, 'objective': 'reg:squarederror', 'n_estimators': 900, 'max_depth': 8, 'learning_rate': 0.1, 'colsample_bytree': 0.8999999999999999, 'colsample_bylevel': 0.7999999999999999}

# %% [markdown]
# ![image-2.png](attachment:image-2.png)!

# %% [markdown]
# #### Best Model

# %%
xgb_model_2 = xgb.train(params = best_model.best_params_, 
                      dtrain = dtrain, 
                      num_boost_round = 4000, 
                      evals = evals, 
                      verbose_eval = 50, # gibt nur alle x Runden aus
                      early_stopping_rounds = 50 # bricht Training ab, wenn val_loss sich für x Runden nicht verbessert
                     )
#xgb_model_2 = xgb.XGBRegressor('subsample': 0.5, 'objective': 'reg:squarederror', 'n_estimators': 150, 'max_depth': 5, 'learning_rate': 0.1, 'colsample_bytree': 0.7999999999999999, 'colsample_bylevel': 0.7) # Initialisierung
#xgb_model_2 = xgb.XGBRegressor(best_model.best_params_) # Initialisierung

# xgb_model_2.fit(X_train, y_train, eval_set = [(X_test, y_test)])

# score_xgb_train = xgb_model.score(X_train, y_train)
# score_xgb_test = xgb_model.score(X_test, y_test)
# print('R^2 Train:', score_xgb_train)
# print('R^2 Test:', score_xgb_test)
# Out:
# [15:06:15] WARNING: C:\Users\dev-admin\croot2\xgboost-split_1675461376218\work\src\learner.cc:767:
# Parameters: { "n_estimators" } are not used.
#
# [0]	train-rmse:1.92024	validation-rmse:1.93777
# [50]	train-rmse:1.20218	validation-rmse:1.22247
# [100]	train-rmse:0.76047	validation-rmse:0.78805
# [150]	train-rmse:0.48202	validation-rmse:0.51671
# [200]	train-rmse:0.30771	validation-rmse:0.35162
# [250]	train-rmse:0.19971	validation-rmse:0.25439
# [300]	train-rmse:0.13217	validation-rmse:0.19790
# [350]	train-rmse:0.08886	validation-rmse:0.16438
# [400]	train-rmse:0.06101	validation-rmse:0.14461
# [450]	train-rmse:0.04330	validation-rmse:0.13295
# [500]	train-rmse:0.03186	validation-rmse:0.12581
# [550]	train-rmse:0.02430	validation-rmse:0.12107
# [600]	train-rmse:0.01926	validation-rmse:0.11796
# [650]	train-rmse:0.01578	validation-rmse:0.11574
# [700]	train-rmse:0.01335	validation-rmse:0.11412
# [750]	train-rmse:0.01160	validation-rmse:0.11302
# [800]	train-rmse:0.01021	validation-rmse:0.11216
# [850]	train-rmse:0.00920	validation-rmse:0.11155
# [900]	train-rmse:0.00839	validation-rmse:0.11108
# [950]	train-rmse:0.00770	validation-rmse:0.11072
# [1000]	train-rmse:0.00700	validation-rmse:0.11040
# [1050]	train-rmse:0.00639	validation-rmse:0.11013
# [1100]	train-rmse:0.00586	validation-rmse:0.10992
# [1150]	train-rmse:0.00533	validation-rmse:0.10975
# [1200]	train-rmse:0.00487	validation-rmse:0.10960
# [1250]	train-rmse:0.00450	validation-rmse:0.10948
# [1300]	train-rmse:0.00414	validation-rmse:0.10939
# [1350]	train-rmse:0.00377	validation-rmse:0.10930
# [1400]	train-rmse:0.00344	validation-rmse:0.10922
# [1450]	train-rmse:0.00316	validation-rmse:0.10915
# [1500]	train-rmse:0.00292	validation-rmse:0.10909
# [1550]	train-rmse:0.00267	validation-rmse:0.10904
# [1600]	train-rmse:0.00247	validation-rmse:0.10900
# [1650]	train-rmse:0.00227	validation-rmse:0.10896
# [1700]	train-rmse:0.00209	validation-rmse:0.10892
# [1750]	train-rmse:0.00194	validation-rmse:0.10889
# [1800]	train-rmse:0.00179	validation-rmse:0.10887
# [1850]	train-rmse:0.00165	validation-rmse:0.10884
# [1900]	train-rmse:0.00152	validation-rmse:0.10882
# [1950]	train-rmse:0.00142	validation-rmse:0.10880
# [2000]	train-rmse:0.00132	validation-rmse:0.10878
# [2050]	train-rmse:0.00125	validation-rmse:0.10876
# [2100]	train-rmse:0.00118	validation-rmse:0.10875
# [2150]	train-rmse:0.00112	validation-rmse:0.10874
# [2200]	train-rmse:0.00108	validation-rmse:0.10873
# [2250]	train-rmse:0.00104	validation-rmse:0.10873
# [2300]	train-rmse:0.00102	validation-rmse:0.10872
# [2350]	train-rmse:0.00100	validation-rmse:0.10872
# [2400]	train-rmse:0.00098	validation-rmse:0.10872
# [2450]	train-rmse:0.00097	validation-rmse:0.10871
# [2500]	train-rmse:0.00096	validation-rmse:0.10871
# [2550]	train-rmse:0.00094	validation-rmse:0.10871
# [2600]	train-rmse:0.00094	validation-rmse:0.10871
# [2650]	train-rmse:0.00093	validation-rmse:0.10871
# [2700]	train-rmse:0.00092	validation-rmse:0.10871
# [2750]	train-rmse:0.00091	validation-rmse:0.10870
# [2800]	train-rmse:0.00090	validation-rmse:0.10870
# [2850]	train-rmse:0.00090	validation-rmse:0.10870
# [2900]	train-rmse:0.00090	validation-rmse:0.10870
# [2950]	train-rmse:0.00090	validation-rmse:0.10870
# [3000]	train-rmse:0.00089	validation-rmse:0.10870
# [3050]	train-rmse:0.00089	validation-rmse:0.10870
# [3100]	train-rmse:0.00088	validation-rmse:0.10870
# [3118]	train-rmse:0.00088	validation-rmse:0.10870

# %%
# Vorhersage der GGW Daten
pred_train_norm = xgb_model_2.predict(dtrain)
pred_test_norm = xgb_model_2.predict(dtest)

# Denormalisierung
pred_train = pred_train_norm * std_out + mean_out
real_train = y_train * std_out + mean_out
pred_test = pred_test_norm * std_out + mean_out
real_test = y_test * std_out + mean_out

mae_train = (abs(real_train - pred_train)).mean()
mae_test = (abs(real_test - pred_test)).mean()
mre_train = (abs((real_train - pred_train) / real_train)).mean()
mre_test = (abs((real_test - pred_test) / real_test)).mean()

print('MAE Train:', mae_train, 'MRE Train:', mre_train, 'MAE Test:', mae_test, 'MRE Test:', mre_test)
# Out:
# MAE Train: 8.798146945892801e-05 MRE Train: 0.0004152716435347018 MAE Test: 0.009940124936506416 MRE Test: 0.04447120113792236

# %%
print('Training Dataset: R^2 =', r2(real_train,pred_train))
print('Test Dataset: R^2 =', r2(real_test,pred_test))
print('Max Error Training: |x_H2 - x_H2_pred| =', max_error(real_train[0], pred_train[0]), '|x_NH3 - x_NH3_pred| =', max_error(real_train[1], pred_train[1]))
print('Max Error Test: |x_H2 - x_H2_pred| =', max_error(real_test[0], pred_test[0]), '|x_NH3 - x_NH3_pred| =', max_error(real_test[1], pred_test[1]))

# find the boundaries of X and Y values
bounds = (min(real_train.min(), pred_train.min()) - int(0.1 * pred_train.min()), max(real_train.max(), pred_train.max())+ int(0.1 * pred_train.max()))

fig,ax = plt.subplots(1,2, figsize =(10,10))

# # Reset the limits
# ax[0] = plt.gca()
ax[0].set_xlim(bounds)
ax[0].set_ylim(bounds)
# Ensure the aspect ratio is square
ax[0].set_aspect("equal", adjustable="box")

ax[0].plot(real_train, pred_train, '.', label = (['$x\mathregular{_{H_2}}$', '$x\mathregular{_{NH_3}}$']))
ax[0].plot([0, 1], [0, 1], "r-",lw=2 ,transform=ax[0].transAxes)
ax[0].plot([bounds[0],bounds[1]], [bounds[0] * 1.1, bounds[1]*1.1], "k--", label = ('\xb1' '10%')) # Error line
ax[0].plot([bounds[0],bounds[1]], [bounds[0] * 0.9, bounds[1]*0.9], "k--") # Error line
ax[0].set(xlabel = '$x$ / 1', ylabel = '$x\mathregular{_{pred}}$ / 1')
ax[0].tick_params(direction = 'in') #, length = 20, width = 3)
ax[0].set_title('Train Data')
ax[0].legend()

# Reset the limits
#ax[1] = plt.gca()
ax[1].set_xlim(bounds)
ax[1].set_ylim(bounds)
# Ensure the aspect ratio is square
ax[1].set_aspect("equal", adjustable="box")

ax[1].plot(real_test, pred_test, '.', label = (['$x\mathregular{_{H_2}}$', '$x\mathregular{_{NH_3}}$']))
ax[1].plot([0, 1], [0, 1], "r-",lw=2 ,transform=ax[1].transAxes)
ax[1].plot([bounds[0],bounds[1]], [bounds[0] * 1.1, bounds[1]*1.1], "k--", label = ('\xb1' '10%')) # Error line
ax[1].plot([bounds[0],bounds[1]], [bounds[0] * 0.9, bounds[1]*0.9], "k--") # Error line
ax[1].set(xlabel = '$x$ / 1', ylabel = '$x\mathregular{_{pred}}$ / 1')
ax[1].tick_params(direction = 'in') #, length = 20, width = 3)
ax[1].set_title('Test Data')
ax[1].legend()

#plt.legend()
#fig.suptitle("Parity Plot")
plt.tight_layout()
plt.show()
# Out:
# Training Dataset: R^2 = 0.999942850764172
# Test Dataset: R^2 = 0.9933618294596233
# Max Error Training: |x_H2 - x_H2_pred| = 0.0012978920496590773 |x_NH3 - x_NH3_pred| = 0.0004051561287993777
# Max Error Test: |x_H2 - x_H2_pred| = 0.005775425092003017 |x_NH3 - x_NH3_pred| = 0.019974476261855834
